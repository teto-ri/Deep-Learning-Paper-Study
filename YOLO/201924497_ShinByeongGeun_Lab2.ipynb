# %% [markdown]
# #LAB 2: YOLO detection model

# %% [markdown]
# <h2><span style="color:blue">신병근</span> </h2>

# %%
import datetime
print("This code is written at " + str(datetime.datetime.now()))
# Out:
# This code is written at 2024-10-30 01:14:05.394135

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision.transforms as transforms
import torch.utils.data as data
from torch.autograd import Variable

import torchvision.datasets as dsets

import numpy as np
import cv2

import os
import struct
import copy
import random

import time
import datetime

import math

from PIL import Image
import torchvision.transforms as transforms
from torchvision.transforms import Compose, ToTensor, Resize
from torch.utils import data
from torch.utils.data import DataLoader

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. What is the Object Detection?
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1pOo5As8Qo8bQOQjOkkpRwjVKcKNB4gSE" alt="no_image" style="width: 800px;"/>
# >
# > - The difference between $\bf{classification}$ (left) and $\bf{detection}$ (right) is simple
# >
# > - In image classification, the entire image is classified with a single label
# >
# > - In object detection, the network localizes (potentially multiple) objects within the image
# >
# > - Therefore, given the image, the obejct detection networks ouput a list of bounding box, class label, and **probability/confidence score**
# >
#
# ### 2. About YOLO (Main idea)
#
# >
# > <img src="https://drive.google.com/uc?export=view&id=1K7tvcGXdRHBc_t5p-m3uyRrCBFbJ9ze5" alt="no_image" style="width: 800px;"/>
# >
# > - YOLO is an algorithm for object detection
# >
# > - They reframe object detection as a $\bf{single\ regression\ problem}$, straight from image pixels to bounding box coordinates and class probabilities
# >
# > - Using YOLO, you only look once (YOLO) at an image to predict what objects are present and where they are
# >
# > - The advantage of YOLO is the speed, which is extremely fast, since the authors reframe detection as a regression problem not using a complex pipeline
# >
# > - What are differences between YOLO and previous detectors?? Refer to https://towardsdatascience.com/r-cnn-fast-r-cnn-faster-r-cnn-yolo-object-detection-algorithms-36d53571365e

# %% [markdown]
# ### 3. Building a YOLO with PyTorch
#
# > ### YOLO model:
# > - 22Convolutional Layers
# >
# >     - Note that, first and 20th conv layers have stride 2 for halving output size
# >
# > - 4 Max Pooling Layers
# >
# > - 2 Fully Connected Layers
# >
# > - Leaky ReLu Activation for all layers except for the last layer
#
# ### 4. Implementing YOLO
# >
# > - The input image is divided into an S $\times$ S grid of cells
# >
# > - Each grid cell predicts B (=2) bounding boxes as well as C (=20) class probabilities
# >
# > - Each bounding box consists of 5 predictions: x, y, w, h, and confidence
# >
# > - The (x,y) coordinates represent the center of the box relative to the bounds of the grid cell
# >
# > - The width and height are predicted relative to the whole image
# >
# > - If no object exists in that cell, the confidence score is zero.
# >
# > - If the cell contains objects, the confidence score is equal to the intersection over union (IOU) between the predicted box and the ground truth (**This is important for building the loss function**)
# >
# > - Thus, the output vector is a S $\times$ S $\times$ (B $\times$ 5 + C) (= 7 $\times$ 7 $\times$ 30)
# >
# > <img src="https://drive.google.com/uc?export=view&id=1LdKtTyYjGKKWmu-4nTYBEMI7n4Sk0aeB" alt="no_image" style="width: 600px;"/>
# >
# > - You must study *generate_target* function in detail, it contains the process of generating output vectors
# >
# > Step 1: Load the dataset
# >
# > Step 2: Build the YOLO network ($\bf{4 points}$)
# >>
# >>  <img src="https://drive.google.com/uc?export=view&id=1c4yOWTZacei0_pFoI47wfxVEhM5Tms8X" alt="no_image" style="width: 800px;"/>
# >>
# >> - Following the YOLO model, you build yolo network
# >> - **Note that our model is different from network of original paper. Please follow above figure.**
# >> - You must fill out the blank in **self.pre_train_net** and **self.post_net** blocks
# >> - All layers use the following Leaky ReLU (0.1 slope for negative part (default=0.01))
# >>
# >>
# >> #### **self.pre_train_net**
# >>
# >>
# >>
# >>| Name       | Filters              | Output Dimension | Padding |
# >>|------------|----------------------|------------------| ------- |
# >>| Conv 1     | 7 x 7 x 64, stride=2 | 224 x 224 x 64   | 3       |
# >>| LeakyReLU  | negative_slop=0.1   | 224 x 224 x 64   |         |
# >>| Max Pool 1 | 2 x 2, stride=2      | 112 x 112 x 64   |         |
# >>|
# >>| Conv 2     | 3 x 3 x 192          | 112 x 112 x 192  | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 112 x 112 x 192  |         |
# >>| Max Pool 2 | 2 x 2, stride=2      | 56 x 56 x 192    |         |
# >>|
# >>| Conv 3     | 1 x 1 x 128          | 56 x 56 x 128    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 128    |         |
# >>| Conv 4     | 3 x 3 x 256          | 56 x 56 x 256    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 5     | 1 x 1 x 256          | 56 x 56 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 256    |         |
# >>| Conv 6     | 3 x 3 x 512          | 56 x 56 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 56 x 56 x 512    |         |
# >>| Max Pool 3 | 2 x 2, stride=2      | 28 x 28 x 512    |         |
# >>|
# >>| Conv 7     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 8     | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 9     | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 10    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 11    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 12    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 13    | 1 x 1 x 256          | 28 x 28 x 256    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 256    |         |
# >>| Conv 14    | 3 x 3 x 512          | 28 x 28 x 512    | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 15    | 1 x 1 x 512          | 28 x 28 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 512    |         |
# >>| Conv 16    | 3 x 3 x 1024         | 28 x 28 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 28 x 28 x 1024   |         |
# >>| Max Pool 4 | 2 x 2, stride=2      | 14 x 14 x 1024   |         |
# >>|
# >>| Conv 17    | 1 x 1 x 512          | 14 x 14 x 512    | 0       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 512    |         |
# >>| Conv 18    | 3 x 3 x 1024         | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU  | negative_slop=0.1   | 14 x 14 x 1024   |         |
# >>
# >> #### **self.post_net**
# >>
# >>| Name      | Filters                | Output Dimension | Padding |
# >>|-----------|------------------------|------------------| ------- |
# >>| Conv 19   | 3 x 3 x 1024           | 14 x 14 x 1024   | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 14 x 14 x 1024   |         |
# >>| Conv 20   | 3 x 3 x 1024, stride=2 | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 21   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>| Conv 22   | 3 x 3 x 1024           | 7 x 7 x 1024     | 1       |
# >>| LeakyReLU | negative_slop=0.1     | 7 x 7 x 1024     |         |
# >>
# > Step 3: Loss function ($\bf{6 points}$)
# >
# >> - Fill out the code considering the loss function in YOLO
# >> - The loss function is composed like below
# >> <img src="https://drive.google.com/uc?export=view&id=1QcAP__J50M379GAul7SlhAzzU551tuDj" alt="no_image" style="width: 600px;"/>
# >>
# >> - $\mathbb{1}_{obj}$ is defined as follows:
# >>    - 1, if an object is present in grid cell $i$ and the $j$th bounding box predictor
# >>    - 0, otherwise
# >>
# >> - YOLO predicts multiple bounding boxes per grid cell (in our case, 2 bounding boxes are predicted)
# >> - In train stage, YOLO requires one bounding box predictor to be responsible for each object
# >> - The code assigns one predictor to be "responsible" for predicting an object where the predictor has the highest IOU with the ground truth
# >> - The loss function is divided into the three sub-sections
# >>    1. Classification ( $\bf{6}$ classes ) ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=13mnxg_GNtbWnYLpe1P6zopf693zTYe22" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Similar to sum-squared error for classification except for $\mathbb{1}_{obj}$ term
# >>
# >>       - Note that, we do not penalize classification error when no object is present on the cell (by $\mathbb{1}_{obj}$ term)
# >>
# >>    2. No object appears in cell ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1R74HzbRLoX2K5zun8XSLAnRQlKq25XFV" alt="no_image" style="width: 300px;"/>
# >>
# >>       - Compute the loss associated with the confidence score for each bounding box predictor
# >>
# >>       - $\mathbb{1}_{noobj}$ is equal to one when there is no object in the cell, and 0 other wise
# >>    3. Bounding box coordinates (x,y,h,w) regression (4 scalars), and Object confidence ($\bf{2 points}$)
# >>       <img src="https://drive.google.com/uc?export=view&id=1lXs5lHUiXGxgMRNCiViY6SyRDL52gQsy" alt="no_image" style="width: 600px;"/>
# >>
# >>       - Compute the loss realted to the predicted bounding box position $(x,y)$ and width/height $(w,h)$
# >>
# >>       - Note that width/height are adapted square root before computing the loss
# >>
# >>       - In order to solve the problem that small deviations in large boxes matter less than in small boxes
# >>
# >>       - Compute the loss associated with the confidence score for the cell which is responsible for the object
# >>
# >> - Following the paper, $\lambda_{coord} = 5$ and $\lambda_{noobj} = 0.5$
# >>
# > Step 4: Train Model ($\bf{2 points}$)
# >>
# >> - Based on the above code, you build train code on your own
# >> - The necessary things are provided (e.g., *optimizer* and *num_epoch*)
# >> - Note that, we offer the pre-trained model (0.685 mAP) since it requires large training time.
# >> - If you construct your code correctly, the performance of mAP will be over 0.7 mAP in 10 epochs (about 15 minitues.)
# >>
# > Step 5: Inference
# >>
# >> - We offer the test code in below
# >> - You can check the qualitative results using the visualization code
# >> - The quantitative results will be evaluated by using the mAP code
# >> - If the performance of mAP is significantly decreased from the pre-trained model (0.685 mAP), your code will be wrong
# >>
# >> Step 5-1: Inference (Visualization)
# >>
# >> Step 5-2: Inference (mAP)

# %% [markdown]
# ### Step 1. Load the dataset

# %%
class YoloDataset(data.Dataset):
    def __init__(self, root, list_file, train, transform=None):
        self.image_size = 448
        self.root = root
        self.train = train
        self.transform = transform
        self.fnames = []
        self.boxes = []
        self.labels = []
        self.color_jitter = Compose([transforms.ColorJitter(brightness=0.1,contrast=0.1, saturation=0.1, hue=0.1),
                                                 transforms.ToTensor()])
        self.plain = Compose([transforms.ToTensor()])
        self.resize = Compose([transforms.ToPILImage(),
                              transforms.Resize((self.image_size, self.image_size)),
                              transforms.ToTensor()])

        with open(list_file) as f:
            lines = f.readlines()

        for line in lines:
            splited = line.strip().split()
            self.fnames.append(splited[0])
            num_boxes = (len(splited) - 1) // 5
            box = []
            label = []
            for i in range(num_boxes):
                x_min = float(splited[1+5*i])
                y_min = float(splited[2+5*i])
                x_max = float(splited[3+5*i])
                y_max = float(splited[4+5*i])
                c = splited[5+5*i]
                box.append([x_min, y_min, x_max, y_max])
                label.append(int(c)+1)
            self.boxes.append(torch.Tensor(box))
            self.labels.append(torch.LongTensor(label))
        self.num_samples = len(self.boxes)

    def img_pre_process(self, img, boxes, labels):

        if random.random() < 0.5:
            im_lr = np.fliplr(img).copy()
            height, width, c = img.shape
            x_min = width - boxes[:, 2]
            x_max = width - boxes[:, 0]
            boxes[:,0] = x_min
            boxes[:,2] = x_max
            img = im_lr

        ## Converting the image and box information scaling
        if random.random() < 0.5:
            scale = random.uniform(0.8, 1.2)
            height, width, c = img.shape
            img = cv2.resize(img, (int(width * scale), height))
            boxes = boxes * torch.FloatTensor([[scale, 1, scale, 1]]).expand_as(boxes)

        ## Image translation
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            shifted_img = np.zeros((height, width, c), dtype=img.dtype)

            w_range = int(random.uniform(-width*0.2, width*0.2))
            h_range = int(random.uniform(-height*0.2, height*0.2))

            if w_range<0 and h_range<0:
                shifted_img[:height+h_range,:width+w_range,:] = img[-h_range:,-w_range:,:]

            elif w_range<0 and h_range>=0:
                shifted_img[h_range:,:width+w_range,:] = img[:height-h_range,-w_range:,:]

            elif w_range>=0 and h_range>=0:
                shifted_img[h_range:,w_range:,:] = img[:height-h_range,:width-w_range,:]

            elif w_range>=0 and h_range<0:
                shifted_img[:height+h_range,w_range:,:] = img[-h_range:,:width-w_range,:]

            wh_range = torch.FloatTensor([[w_range, h_range]]).expand_as(center)
            center = center + wh_range

            mask1 = (center[:,0] > 0) & (center[:,0] < width)
            mask2 = (center[:,1] > 0) & (center[:,1] < height)
            mask = (mask1 & mask2).view(-1,1)

            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)

            if len(boxes_in) != 0:
                box_shift = torch.FloatTensor([[w_range, h_range, w_range, h_range]]).expand_as(boxes_in)
                boxes_in = boxes_in + box_shift

                labels_in = labels[mask.view(-1)]
                labels = labels_in
                img = shifted_img
                boxes = boxes_in

        ## Image cropping
        if random.random() < 0.5:
            center = (boxes[:,2:] + boxes[:,:2]) / 2
            height, width, c = img.shape
            h = int(random.uniform(0.6*height,height))
            w = int(random.uniform(0.6*width,width))
            x = int(random.uniform(0,width-w))
            y = int(random.uniform(0,height-h))

            center = center - torch.FloatTensor([[x, y]]).expand_as(center)
            mask1 = (center[:,0]>0) & (center[:,0]<w)
            mask2 = (center[:,1]>0) & (center[:,1]<h)
            mask = (mask1 & mask2).view(-1, 1)

            boxes_in = boxes[mask.expand_as(boxes)].view(-1,4)

            if (len(boxes_in)!=0):
                box_shift = torch.FloatTensor([x,y,x,y]).expand_as(boxes_in)

                boxes_in = boxes_in - box_shift
                boxes_in[:,0]=boxes_in[:,0].clamp_(min=0,max=w)
                boxes_in[:,2]=boxes_in[:,2].clamp_(min=0,max=w)
                boxes_in[:,1]=boxes_in[:,1].clamp_(min=0,max=h)
                boxes_in[:,3]=boxes_in[:,3].clamp_(min=0,max=h)

                labels = labels[mask.view(-1)]
                img_cropped = img[y:y+h, x:x+w, :]
                boxes = boxes_in
                img = img_cropped

        return img, boxes, labels

    def generate_target(self, img, boxes, labels):
        grid_size = 7
        h,w,_ = img.shape
        boxes /= torch.Tensor([w,h,w,h]).expand_as(boxes) # Converting the box size 0 ~ 1
        target = torch.zeros((grid_size, grid_size, 30))
        cell_size = 1./grid_size

        wh = boxes[:,2:] - boxes[:,:2]
        cxcy = (boxes[:,2:] + boxes[:,:2]) / 2

        for i in range(cxcy.size()[0]):
            cxcy_sample = cxcy[i] # center pixel
            ij = (cxcy_sample/cell_size).ceil()-1
            target[int(ij[1]),int(ij[0]),4] = 1
            target[int(ij[1]),int(ij[0]),9] = 1
            target[int(ij[1]),int(ij[0]),int(labels[i])+9] = 1

            xy = ij*cell_size
            delta_xy = (cxcy_sample -xy)/cell_size # Converting delta_xy to the size
                                                   # relative to the bounds of the grid cell
            target[int(ij[1]),int(ij[0]),2:4] = wh[i]
            target[int(ij[1]),int(ij[0]),:2] = delta_xy
            target[int(ij[1]),int(ij[0]),7:9] = wh[i]
            target[int(ij[1]),int(ij[0]),5:7] = delta_xy

        return target

    def RandomBrightness(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            v = v*adjust
            v = np.clip(v, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomSaturation(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            s = s*adjust
            s = np.clip(s, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr
    def RandomHue(self,bgr):
        if random.random() < 0.5:
            hsv = cv2.cvtColor(bgr,cv2.COLOR_BGR2HSV)
            h,s,v = cv2.split(hsv)
            adjust = random.choice([0.5,1.5])
            h = h*adjust
            h = np.clip(h, 0, 255).astype(hsv.dtype)
            hsv = cv2.merge((h,s,v))
            bgr = cv2.cvtColor(hsv,cv2.COLOR_HSV2BGR)
        return bgr

    def randomBlur(self,bgr):
        if random.random()<0.5:
            bgr = cv2.blur(bgr,(5,5))
        return bgr

    def __getitem__(self, idx):
        fname = self.fnames[idx]
        img = cv2.imread(os.path.join(self.root+fname))
        boxes = self.boxes[idx].clone()
        labels = self.labels[idx].clone()

        if self.train:
            img = self.randomBlur(img)
            img = self.RandomBrightness(img)
            img = self.RandomHue(img)
            img = self.RandomSaturation(img)
            img, boxes, labels = self.img_pre_process(img, boxes, labels)

        target = self.generate_target(img, boxes, labels) # 7x7x30

        # Image processing
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        img = self.plain(img)
        img = self.resize(img)
        img = 2 * img - 1

        return img, target

    def __len__(self):
        return self.num_samples

# %% [markdown]
# ### Step 2. Build the YOLO network (2 points)

# %% [markdown]
# > You should build model using nn.Sequential. Otherwise, problem arises when loading pretrained weights.

# %%
class YOLO(nn.Module):
    def __init__(self):
        super(YOLO, self).__init__()

        self.pre_train_net = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=7, stride=2, padding=3),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 192, kernel_size=3, stride=1, padding=1),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(192, 128, kernel_size=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(256, 256, kernel_size=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(512, 256, kernel_size=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(512, 256, kernel_size=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(512, 256, kernel_size=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(512, 256, kernel_size=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(512, 512, kernel_size=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(512, 1024, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(1024, 512, kernel_size=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(512, 1024, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1)
        )

        self.post_net = nn.Sequential(
            nn.Conv2d(1024, 1024, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(1024, 1024, kernel_size=3, stride=2, padding=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(1024, 1024, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
            nn.Conv2d(1024, 1024, kernel_size=3, padding=1),
            nn.LeakyReLU(0.1),
        )

        self.FC1 = nn.Sequential(
            nn.Linear(50176, 4096),
            nn.LeakyReLU(),
            nn.Dropout()
        )

        self.FC2 = nn.Sequential(
            nn.Linear(4096, 1470)
        )

        self.pre_train_net.cuda()
        self.post_net.cuda()
        self.FC1.cuda()
        self.FC2.cuda()

        self._initialize_weights()
        
    def forward(self, x):
        output = self.pre_train_net(x)
        output = self.post_net(output)

        # Ready to going for FC layer
        output = output.view(output.size(0), -1)

        output = self.FC1(output)
        output = self.FC2(output)

        output = output.view(output.size(0), 7, 7, 30)
        # Converting the output shape to the (batch_size, 7, 7, 30)
        output = F.relu(output)

        return output

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
                if m.bias is not None:
                    m.bias.data.zero_()
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.weight.data.normal_(0, 0.01)
                m.bias.data.zero_()

# %% [markdown]
# ### Step 3. Loss function (6 points)

# %%
class yoloLoss(nn.Module):
    def __init__(self,l_coord,l_noobj):
        super(yoloLoss,self).__init__()
        self.l_coord = l_coord
        self.l_noobj = l_noobj

    def compute_prob_error(self, pred, target): ## classification error
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]

        prediction = pred[contain].view(-1, 30)
        classes_p = prediction[:, 10:]
        targeting = target[contain].view(-1, 30)
        classes_t = targeting[:, 10:]

        prob_loss = F.mse_loss(classes_p, classes_t, reduction='sum') # classification error 계산

        return prob_loss

    def not_contain_obj_error(self, pred, target): ## Error where no object appears in cell
        not_contain = target[:, :, :, 4] == 0 # [Batch_size, 7, 7, 1]
        not_contain = not_contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]

        predictions_no_obj = pred[not_contain].view(-1, 30)
        targets_no_obj = target[not_contain].view(-1, 30)

        # Create a boolean mask for confidence predictions
        confidence_mask = torch.zeros(predictions_no_obj.size(), dtype=torch.bool, device=predictions_no_obj.device)
        confidence_mask[:, 4] = 1  # Confidence for class 1
        confidence_mask[:, 9] = 1  # Confidence for class 2

        # Select predictions and targets based on the mask
        conf_predictions = predictions_no_obj[confidence_mask]
        conf_targets = targets_no_obj[confidence_mask]
        
        # Calculate Mean Squared Error Loss for no object cases
        noobj_loss1 = F.mse_loss(conf_predictions, conf_targets, reduction='sum')
        
        return noobj_loss1


    def contain_obj_error(self, pred, target): ##
        contain = target[:,:,:,4] > 0 # [Batch_size, 7, 7, 1]
        contain = contain.unsqueeze(3).expand_as(target) # [Batch_size, 7, 7, 30]

        contain_pred = pred[contain].contiguous().view(-1,30) # Only cell which contains the object are remained
        box_pred = contain_pred[:,:10].contiguous().view(-1,5) # Reshaping

        contain_target = target[contain].contiguous().view(-1,30)
        box_target = contain_target[:,:10].contiguous().view(-1,5)

        # Note that, We assign one predictor to be "responsible" for predicting
        # an object based on which prediction has the highest current IOU with the ground truth
        # Then, other prediction is "not responsible" for predicting an object
        # That component is included in "contain_noobj_mask variables

        contain_obj_mask = torch.zeros_like(box_target, dtype=torch.bool) # Create the mask
        contain_noobj_mask = torch.zeros_like(box_target, dtype=torch.bool)

        target_iou_gt = torch.zeros(box_target[:,0].size()).cuda() # In order to save the IoU for confidence
                                                                   # of the cell which contains object

        for i in range(0, box_target.size()[0], 2):
            box_p = box_pred[i:i+2] # For 2 bounding boxes information
            box_p_coord = Variable(torch.FloatTensor(box_p.size())) # Box coordinate (x_min, y_min, x_max, y_max)
            
            box_p_coord[:,:2] = box_p[:, :2] - box_p[:, 2:4] / 2  # x_min, y_min
            box_p_coord[:,2:4] = box_p[:, :2] + box_p[:, 2:4] / 2  # x_max, y_max

            box_t = box_target[i].contiguous().view(-1,5)
            box_t_coord = Variable(torch.FloatTensor(box_t.size()))
            
            box_t_coord[:,:2] = box_t[:, :2] - box_t[:, 2:4] / 2
            box_t_coord[:,2:4] = box_t[:, :2] + box_t[:, 2:4] / 2

            iou = self.compute_iou(box_p_coord[:,:4], box_t_coord[:,:4]) # [2,]
                                                      # compute IoU between prediction and target boxes,

            gt_iou, max_idx = iou.max(0)
            contain_obj_mask[i+max_idx] = 1
            contain_noobj_mask[i+1-max_idx] = 1

            target_iou_gt[i+max_idx] = gt_iou.data.cuda()

        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        target_iou_gt = target_iou_gt.to(device)

        ## For the cell which contains object
        contain_box_pred = box_pred[contain_obj_mask].view(-1, 5)


        ## For the cell which does not contain object
        not_contain_box_pred = box_pred[contain_noobj_mask].view(-1, 5)

        ## For target domain
        contain_box_target = box_target[contain_obj_mask].view(-1, 5)

        not_contain_box_target = box_target[contain_noobj_mask].view(-1, 5)
        not_contain_box_target[:,4] = 0

        ## For the GT IoU
        contain_iou_target = target_iou_gt[contain_obj_mask[:, 4]]


        obj_loss = F.mse_loss(contain_box_pred[:,4], contain_iou_target, size_average=False)
        xy_loss = F.mse_loss(contain_box_pred[:,:2], contain_box_target[:,:2], size_average=False)
        wh_loss = F.mse_loss(torch.sqrt(contain_box_pred[:,2:4]), torch.sqrt(contain_box_target[:,2:4]), size_average=False)
        noobj_loss2 = F.mse_loss(not_contain_box_pred[:,4], not_contain_box_target[:,4], size_average=False)

        return obj_loss, xy_loss, wh_loss, noobj_loss2

    def compute_iou(self, box_p, box_t):

        pred_area = (box_p[:,2] - box_p[:,0]) * (box_p[:,3] - box_p[:,1]) # [2,]
        target_area = (box_t[:,2] - box_t[:,0]) * (box_t[:,3] - box_t[:,1]) #[1,]

        box_p = box_p.unsqueeze(1).expand(2,1,4)
        box_t = box_t.unsqueeze(0).expand(2,1,4)

        inter_lt = torch.max(box_p[:,:,:2], box_t[:,:,:2]) # [2,1,2]

        inter_rb = torch.min(box_p[:,:,2:], box_t[:,:,2:]) # [2,1,2]

        wh = inter_rb - inter_lt # [2,1,2]
        wh[wh<0] = 0

        inter_area = wh[:,:,0] * wh[:,:,1] # [2,1]
        pred_area = pred_area.unsqueeze(1).expand_as(inter_area)
        target_area = target_area.unsqueeze(0).expand_as(inter_area)

        iou = inter_area / (pred_area + target_area - inter_area)

        return iou

    def forward(self,pred,target):

        batch_size = pred.size()[0]

        noobj_loss1 = self.not_contain_obj_error(pred, target)
        prob_loss = self.compute_prob_error(pred, target)
        obj_loss, xy_loss, wh_loss, noobj_loss2 = self.contain_obj_error(pred, target)

        total_loss = (self.l_coord*(xy_loss + wh_loss) + obj_loss + self.l_noobj*(noobj_loss1 + noobj_loss2) + prob_loss)

        return total_loss / batch_size

# %% [markdown]
# ### Step 4. Train the model

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
file_root = './lab2/all_img/'
train_dataset = YoloDataset(root=file_root, list_file='./lab2/utils/Generate_dataset/voc2007+2012.txt', train=True)
train_loader = DataLoader(train_dataset, batch_size=10, shuffle=True, num_workers=8)

model = YOLO()
state_dict = torch.load('./lab2/pre_train.pt', map_location='cpu',weights_only=False)
model.load_state_dict(state_dict['state_dict'])

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

learning_rate = 1e-4
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=5e-4)
optimizer.load_state_dict(state_dict['optimizer'])

print('pre_train_complete')
criterion = yoloLoss(l_coord=5,l_noobj=0.5)

best = 1e+30
num_epochs = 15
print("training start!")

for epoch in range(num_epochs):
    model.train()
    total_loss = 0

    for i, (images, target) in enumerate(train_loader):
        images = images.to(device)
        target = target.to(device)

        pred = model(images)
        loss = criterion(pred, target)

        total_loss += loss.item()

        optimizer.zero_grad()
        loss.backward()
        
        # Gradient normalization
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        
        optimizer.step()

        if (i+1) % 10 == 0:
            print('Epoch [%d/%d], Iter [%d,%d] Loss:%.4f, average_loss: %.4f' % (epoch+1, num_epochs, i+1, len(train_loader), loss.item(), total_loss / (i+1)))
# Out:
# pre_train_complete
# training start!
# /home/team116/miniconda3/envs/torch/lib/python3.11/site-packages/torch/nn/_reduction.py:42: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Epoch [1/15], Iter [10,430] Loss:304.7502, average_loss: 389.9671
# Epoch [1/15], Iter [20,430] Loss:132.8874, average_loss: 291.7646
# Epoch [1/15], Iter [30,430] Loss:24.9899, average_loss: 215.6262
# Epoch [1/15], Iter [40,430] Loss:15.9596, average_loss: 167.6162
# Epoch [1/15], Iter [50,430] Loss:8.0474, average_loss: 135.8525
# Epoch [1/15], Iter [60,430] Loss:6.0062, average_loss: 114.4154
# Epoch [1/15], Iter [70,430] Loss:3.2631, average_loss: 98.9302
# Epoch [1/15], Iter [80,430] Loss:2.3256, average_loss: 87.0560
# Epoch [1/15], Iter [90,430] Loss:3.0598, average_loss: 77.7819
# Epoch [1/15], Iter [100,430] Loss:3.1794, average_loss: 70.3230
# Epoch [1/15], Iter [110,430] Loss:2.2089, average_loss: 64.1876
# Epoch [1/15], Iter [120,430] Loss:1.8510, average_loss: 59.0586
# Epoch [1/15], Iter [130,430] Loss:2.1954, average_loss: 54.7239
# Epoch [1/15], Iter [140,430] Loss:1.6687, average_loss: 50.9858
# Epoch [1/15], Iter [150,430] Loss:1.6459, average_loss: 47.7264
# Epoch [1/15], Iter [160,430] Loss:2.4651, average_loss: 44.8855
# Epoch [1/15], Iter [170,430] Loss:1.6089, average_loss: 42.3696
# Epoch [1/15], Iter [180,430] Loss:2.8404, average_loss: 40.1357
# Epoch [1/15], Iter [190,430] Loss:1.6820, average_loss: 38.1227
# Epoch [1/15], Iter [200,430] Loss:1.5451, average_loss: 36.3200
# Epoch [1/15], Iter [210,430] Loss:1.2608, average_loss: 34.6898
# Epoch [1/15], Iter [220,430] Loss:1.6174, average_loss: 33.1852
# Epoch [1/15], Iter [230,430] Loss:1.0964, average_loss: 31.8177
# Epoch [1/15], Iter [240,430] Loss:1.6697, average_loss: 30.5667
# Epoch [1/15], Iter [250,430] Loss:1.4636, average_loss: 29.4176
# Epoch [1/15], Iter [260,430] Loss:1.9695, average_loss: 28.3558
# Epoch [1/15], Iter [270,430] Loss:1.5515, average_loss: 27.3681
# Epoch [1/15], Iter [280,430] Loss:2.0468, average_loss: 26.4631
# Epoch [1/15], Iter [290,430] Loss:1.4785, average_loss: 25.6023
# Epoch [1/15], Iter [300,430] Loss:2.0198, average_loss: 24.8077
# Epoch [1/15], Iter [310,430] Loss:1.8330, average_loss: 24.0693
# Epoch [1/15], Iter [320,430] Loss:1.4896, average_loss: 23.3706
# Epoch [1/15], Iter [330,430] Loss:2.3124, average_loss: 22.7137
# Epoch [1/15], Iter [340,430] Loss:1.3729, average_loss: 22.0860
# Epoch [1/15], Iter [350,430] Loss:1.6722, average_loss: 21.5117
# Epoch [1/15], Iter [360,430] Loss:1.4415, average_loss: 20.9539
# Epoch [1/15], Iter [370,430] Loss:2.5105, average_loss: 20.4359
# Epoch [1/15], Iter [380,430] Loss:2.2600, average_loss: 19.9429
# Epoch [1/15], Iter [390,430] Loss:2.0562, average_loss: 19.4739
# Epoch [1/15], Iter [400,430] Loss:1.7505, average_loss: 19.0204
# Epoch [1/15], Iter [410,430] Loss:1.0127, average_loss: 18.5964
# Epoch [1/15], Iter [420,430] Loss:1.5317, average_loss: 18.1950
# Epoch [1/15], Iter [430,430] Loss:1.6995, average_loss: 17.8092
# Epoch [2/15], Iter [10,430] Loss:1.6567, average_loss: 1.6830
# Epoch [2/15], Iter [20,430] Loss:2.2508, average_loss: 1.6922
# Epoch [2/15], Iter [30,430] Loss:2.0918, average_loss: 1.6235
# Epoch [2/15], Iter [40,430] Loss:1.6757, average_loss: 1.5724
# Epoch [2/15], Iter [50,430] Loss:1.9157, average_loss: 1.5704
# Epoch [2/15], Iter [60,430] Loss:1.0105, average_loss: 1.5861
# Epoch [2/15], Iter [70,430] Loss:1.1380, average_loss: 1.5399
# Epoch [2/15], Iter [80,430] Loss:1.2174, average_loss: 1.5519
# Epoch [2/15], Iter [90,430] Loss:1.6777, average_loss: 1.5241
# Epoch [2/15], Iter [100,430] Loss:1.3886, average_loss: 1.5081
# Epoch [2/15], Iter [110,430] Loss:1.8397, average_loss: 1.5139
# Epoch [2/15], Iter [120,430] Loss:1.1633, average_loss: 1.5197
# Epoch [2/15], Iter [130,430] Loss:1.2572, average_loss: 1.5018
# Epoch [2/15], Iter [140,430] Loss:1.3727, average_loss: 1.5116
# Epoch [2/15], Iter [150,430] Loss:0.9345, average_loss: 1.4993
# Epoch [2/15], Iter [160,430] Loss:0.8287, average_loss: 1.4996
# Epoch [2/15], Iter [170,430] Loss:1.5630, average_loss: 1.4891
# Epoch [2/15], Iter [180,430] Loss:0.8844, average_loss: 1.4828
# Epoch [2/15], Iter [190,430] Loss:0.9746, average_loss: 1.4778
# Epoch [2/15], Iter [200,430] Loss:1.3556, average_loss: 1.4837
# Epoch [2/15], Iter [210,430] Loss:0.8994, average_loss: 1.4744
# Epoch [2/15], Iter [220,430] Loss:0.9016, average_loss: 1.4592
# Epoch [2/15], Iter [230,430] Loss:0.9848, average_loss: 1.4540
# Epoch [2/15], Iter [240,430] Loss:1.1078, average_loss: 1.4516
# Epoch [2/15], Iter [250,430] Loss:1.9315, average_loss: 1.4539
# Epoch [2/15], Iter [260,430] Loss:1.3265, average_loss: 1.4512
# Epoch [2/15], Iter [270,430] Loss:0.8595, average_loss: 1.4430
# Epoch [2/15], Iter [280,430] Loss:1.2852, average_loss: 1.4343
# Epoch [2/15], Iter [290,430] Loss:1.6732, average_loss: 1.4310
# Epoch [2/15], Iter [300,430] Loss:1.8468, average_loss: 1.4245
# Epoch [2/15], Iter [310,430] Loss:1.8044, average_loss: 1.4159
# Epoch [2/15], Iter [320,430] Loss:1.0734, average_loss: 1.4173
# Epoch [2/15], Iter [330,430] Loss:1.1360, average_loss: 1.4199
# Epoch [2/15], Iter [340,430] Loss:1.1453, average_loss: 1.4157
# Epoch [2/15], Iter [350,430] Loss:1.4384, average_loss: 1.4157
# Epoch [2/15], Iter [360,430] Loss:0.7334, average_loss: 1.4092
# Epoch [2/15], Iter [370,430] Loss:0.8233, average_loss: 1.4051
# Epoch [2/15], Iter [380,430] Loss:0.9364, average_loss: 1.3988
# Epoch [2/15], Iter [390,430] Loss:1.3524, average_loss: 1.3938
# Epoch [2/15], Iter [400,430] Loss:1.7222, average_loss: 1.3919
# Epoch [2/15], Iter [410,430] Loss:1.1435, average_loss: 1.3858
# Epoch [2/15], Iter [420,430] Loss:1.4301, average_loss: 1.3803
# Epoch [2/15], Iter [430,430] Loss:1.2296, average_loss: 1.3727
# Epoch [3/15], Iter [10,430] Loss:0.9595, average_loss: 1.0829
# Epoch [3/15], Iter [20,430] Loss:0.8713, average_loss: 1.0921
# Epoch [3/15], Iter [30,430] Loss:1.0178, average_loss: 1.1154
# Epoch [3/15], Iter [40,430] Loss:1.2376, average_loss: 1.1981
# Epoch [3/15], Iter [50,430] Loss:1.7749, average_loss: 1.2127
# Epoch [3/15], Iter [60,430] Loss:1.4972, average_loss: 1.2139
# Epoch [3/15], Iter [70,430] Loss:0.7312, average_loss: 1.2168
# Epoch [3/15], Iter [80,430] Loss:1.1439, average_loss: 1.1914
# Epoch [3/15], Iter [90,430] Loss:0.9785, average_loss: 1.1892
# Epoch [3/15], Iter [100,430] Loss:2.4131, average_loss: 1.1980
# Epoch [3/15], Iter [110,430] Loss:1.1296, average_loss: 1.2076
# Epoch [3/15], Iter [120,430] Loss:1.2672, average_loss: 1.2019
# Epoch [3/15], Iter [130,430] Loss:0.8549, average_loss: 1.1845
# Epoch [3/15], Iter [140,430] Loss:1.0035, average_loss: 1.1831
# Epoch [3/15], Iter [150,430] Loss:1.8217, average_loss: 1.1712
# Epoch [3/15], Iter [160,430] Loss:1.7993, average_loss: 1.1806
# Epoch [3/15], Iter [170,430] Loss:1.1662, average_loss: 1.1799
# Epoch [3/15], Iter [180,430] Loss:2.1707, average_loss: 1.1879
# Epoch [3/15], Iter [190,430] Loss:0.9110, average_loss: 1.1845
# Epoch [3/15], Iter [200,430] Loss:1.3552, average_loss: 1.1863
# Epoch [3/15], Iter [210,430] Loss:1.4027, average_loss: 1.1851
# Epoch [3/15], Iter [220,430] Loss:0.6817, average_loss: 1.1896
# Epoch [3/15], Iter [230,430] Loss:1.0878, average_loss: 1.1907
# Epoch [3/15], Iter [240,430] Loss:0.9330, average_loss: 1.1968
# Epoch [3/15], Iter [250,430] Loss:1.2110, average_loss: 1.1899
# Epoch [3/15], Iter [260,430] Loss:1.0975, average_loss: 1.1879
# Epoch [3/15], Iter [270,430] Loss:0.6085, average_loss: 1.1837
# Epoch [3/15], Iter [280,430] Loss:1.4911, average_loss: 1.1869
# Epoch [3/15], Iter [290,430] Loss:0.6874, average_loss: 1.1869
# Epoch [3/15], Iter [300,430] Loss:1.4865, average_loss: 1.1807
# Epoch [3/15], Iter [310,430] Loss:1.6067, average_loss: 1.1826
# Epoch [3/15], Iter [320,430] Loss:1.1434, average_loss: 1.1784
# Epoch [3/15], Iter [330,430] Loss:1.0513, average_loss: 1.1748
# Epoch [3/15], Iter [340,430] Loss:1.4865, average_loss: 1.1747
# Epoch [3/15], Iter [350,430] Loss:1.0490, average_loss: 1.1724
# Epoch [3/15], Iter [360,430] Loss:0.8373, average_loss: 1.1727
# Epoch [3/15], Iter [370,430] Loss:0.9763, average_loss: 1.1764
# Epoch [3/15], Iter [380,430] Loss:1.6458, average_loss: 1.1760
# Epoch [3/15], Iter [390,430] Loss:1.0895, average_loss: 1.1762
# Epoch [3/15], Iter [400,430] Loss:0.8130, average_loss: 1.1747
# Epoch [3/15], Iter [410,430] Loss:0.7040, average_loss: 1.1791
# Epoch [3/15], Iter [420,430] Loss:0.9514, average_loss: 1.1775
# Epoch [3/15], Iter [430,430] Loss:0.8607, average_loss: 1.1731
# Epoch [4/15], Iter [10,430] Loss:1.2511, average_loss: 1.2602
# Epoch [4/15], Iter [20,430] Loss:1.3517, average_loss: 1.2413
# Epoch [4/15], Iter [30,430] Loss:0.7112, average_loss: 1.1670
# Epoch [4/15], Iter [40,430] Loss:0.9063, average_loss: 1.1879
# Epoch [4/15], Iter [50,430] Loss:0.9678, average_loss: 1.1446
# Epoch [4/15], Iter [60,430] Loss:1.1295, average_loss: 1.1439
# Epoch [4/15], Iter [70,430] Loss:0.8247, average_loss: 1.1272
# Epoch [4/15], Iter [80,430] Loss:0.6931, average_loss: 1.1391
# Epoch [4/15], Iter [90,430] Loss:0.9318, average_loss: 1.1533
# Epoch [4/15], Iter [100,430] Loss:0.8435, average_loss: 1.1550
# Epoch [4/15], Iter [110,430] Loss:0.6567, average_loss: 1.1366
# Epoch [4/15], Iter [120,430] Loss:1.0365, average_loss: 1.1403
# Epoch [4/15], Iter [130,430] Loss:0.7506, average_loss: 1.1331
# Epoch [4/15], Iter [140,430] Loss:0.7201, average_loss: 1.1249
# Epoch [4/15], Iter [150,430] Loss:1.0725, average_loss: 1.1178
# Epoch [4/15], Iter [160,430] Loss:1.4403, average_loss: 1.1274
# Epoch [4/15], Iter [170,430] Loss:1.4500, average_loss: 1.1159
# Epoch [4/15], Iter [180,430] Loss:1.3726, average_loss: 1.1113
# Epoch [4/15], Iter [190,430] Loss:0.7678, average_loss: 1.1092
# Epoch [4/15], Iter [200,430] Loss:0.8693, average_loss: 1.1041
# Epoch [4/15], Iter [210,430] Loss:1.3554, average_loss: 1.1055
# Epoch [4/15], Iter [220,430] Loss:1.7557, average_loss: 1.1055
# Epoch [4/15], Iter [230,430] Loss:0.9249, average_loss: 1.1075
# Epoch [4/15], Iter [240,430] Loss:0.7149, average_loss: 1.1042
# Epoch [4/15], Iter [250,430] Loss:0.9127, average_loss: 1.1047
# Epoch [4/15], Iter [260,430] Loss:1.1229, average_loss: 1.1027
# Epoch [4/15], Iter [270,430] Loss:0.7812, average_loss: 1.1005
# Epoch [4/15], Iter [280,430] Loss:0.5713, average_loss: 1.0979
# Epoch [4/15], Iter [290,430] Loss:0.9406, average_loss: 1.0952
# Epoch [4/15], Iter [300,430] Loss:1.2944, average_loss: 1.0987
# Epoch [4/15], Iter [310,430] Loss:1.2329, average_loss: 1.1110
# Epoch [4/15], Iter [320,430] Loss:1.0177, average_loss: 1.1112
# Epoch [4/15], Iter [330,430] Loss:0.9828, average_loss: 1.1061
# Epoch [4/15], Iter [340,430] Loss:0.8374, average_loss: 1.1046
# Epoch [4/15], Iter [350,430] Loss:0.8191, average_loss: 1.1006
# Epoch [4/15], Iter [360,430] Loss:0.6251, average_loss: 1.0956
# Epoch [4/15], Iter [370,430] Loss:1.0387, average_loss: 1.0960
# Epoch [4/15], Iter [380,430] Loss:1.7071, average_loss: 1.0943
# Epoch [4/15], Iter [390,430] Loss:0.9543, average_loss: 1.0939
# Epoch [4/15], Iter [400,430] Loss:0.7683, average_loss: 1.0887
# Epoch [4/15], Iter [410,430] Loss:1.0042, average_loss: 1.0881
# Epoch [4/15], Iter [420,430] Loss:0.9488, average_loss: 1.0867
# Epoch [4/15], Iter [430,430] Loss:1.0098, average_loss: 1.0841
# Epoch [5/15], Iter [10,430] Loss:1.7053, average_loss: 1.0569
# Epoch [5/15], Iter [20,430] Loss:0.9794, average_loss: 1.0918
# Epoch [5/15], Iter [30,430] Loss:1.7873, average_loss: 1.1048
# Epoch [5/15], Iter [40,430] Loss:0.8043, average_loss: 1.0296
# Epoch [5/15], Iter [50,430] Loss:1.0005, average_loss: 1.0169
# Epoch [5/15], Iter [60,430] Loss:0.8782, average_loss: 1.0096
# Epoch [5/15], Iter [70,430] Loss:1.4177, average_loss: 1.0260
# Epoch [5/15], Iter [80,430] Loss:0.8421, average_loss: 1.0011
# Epoch [5/15], Iter [90,430] Loss:1.2373, average_loss: 1.0064
# Epoch [5/15], Iter [100,430] Loss:0.7653, average_loss: 0.9974
# Epoch [5/15], Iter [110,430] Loss:0.7264, average_loss: 0.9881
# Epoch [5/15], Iter [120,430] Loss:0.6370, average_loss: 0.9773
# Epoch [5/15], Iter [130,430] Loss:1.6564, average_loss: 0.9837
# Epoch [5/15], Iter [140,430] Loss:0.7288, average_loss: 0.9867
# Epoch [5/15], Iter [150,430] Loss:1.8420, average_loss: 1.0107
# Epoch [5/15], Iter [160,430] Loss:0.6987, average_loss: 1.0149
# Epoch [5/15], Iter [170,430] Loss:0.9059, average_loss: 1.0208
# Epoch [5/15], Iter [180,430] Loss:1.1545, average_loss: 1.0252
# Epoch [5/15], Iter [190,430] Loss:1.6479, average_loss: 1.0236
# Epoch [5/15], Iter [200,430] Loss:1.1518, average_loss: 1.0278
# Epoch [5/15], Iter [210,430] Loss:0.8582, average_loss: 1.0285
# Epoch [5/15], Iter [220,430] Loss:0.8518, average_loss: 1.0304
# Epoch [5/15], Iter [230,430] Loss:0.8918, average_loss: 1.0296
# Epoch [5/15], Iter [240,430] Loss:1.2754, average_loss: 1.0244
# Epoch [5/15], Iter [250,430] Loss:1.0219, average_loss: 1.0191
# Epoch [5/15], Iter [260,430] Loss:0.9392, average_loss: 1.0122
# Epoch [5/15], Iter [270,430] Loss:1.4321, average_loss: 1.0097
# Epoch [5/15], Iter [280,430] Loss:0.5953, average_loss: 1.0106
# Epoch [5/15], Iter [290,430] Loss:0.9736, average_loss: 1.0076
# Epoch [5/15], Iter [300,430] Loss:2.4351, average_loss: 1.0068
# Epoch [5/15], Iter [310,430] Loss:1.1530, average_loss: 1.0037
# Epoch [5/15], Iter [320,430] Loss:0.8684, average_loss: 1.0038
# Epoch [5/15], Iter [330,430] Loss:1.3938, average_loss: 1.0084
# Epoch [5/15], Iter [340,430] Loss:1.2528, average_loss: 1.0071
# Epoch [5/15], Iter [350,430] Loss:1.0695, average_loss: 1.0035
# Epoch [5/15], Iter [360,430] Loss:0.9981, average_loss: 1.0000
# Epoch [5/15], Iter [370,430] Loss:1.3411, average_loss: 1.0010
# Epoch [5/15], Iter [380,430] Loss:1.2043, average_loss: 1.0031
# Epoch [5/15], Iter [390,430] Loss:0.4178, average_loss: 0.9975
# Epoch [5/15], Iter [400,430] Loss:0.8844, average_loss: 0.9930
# Epoch [5/15], Iter [410,430] Loss:0.9773, average_loss: 0.9935
# Epoch [5/15], Iter [420,430] Loss:0.8596, average_loss: 0.9892
# Epoch [5/15], Iter [430,430] Loss:0.8967, average_loss: 0.9888
# Epoch [6/15], Iter [10,430] Loss:1.0672, average_loss: 0.9864
# Epoch [6/15], Iter [20,430] Loss:0.8950, average_loss: 0.9921
# Epoch [6/15], Iter [30,430] Loss:1.1542, average_loss: 0.9321
# Epoch [6/15], Iter [40,430] Loss:1.1559, average_loss: 0.9181
# Epoch [6/15], Iter [50,430] Loss:0.5881, average_loss: 0.9274
# Epoch [6/15], Iter [60,430] Loss:0.9434, average_loss: 0.9333
# Epoch [6/15], Iter [70,430] Loss:0.8702, average_loss: 0.9317
# Epoch [6/15], Iter [80,430] Loss:0.8956, average_loss: 0.9140
# Epoch [6/15], Iter [90,430] Loss:0.6967, average_loss: 0.9234
# Epoch [6/15], Iter [100,430] Loss:0.7549, average_loss: 0.9224
# Epoch [6/15], Iter [110,430] Loss:0.5633, average_loss: 0.9342
# Epoch [6/15], Iter [120,430] Loss:0.6373, average_loss: 0.9312
# Epoch [6/15], Iter [130,430] Loss:0.8730, average_loss: 0.9268
# Epoch [6/15], Iter [140,430] Loss:1.0627, average_loss: 0.9262
# Epoch [6/15], Iter [150,430] Loss:1.2617, average_loss: 0.9438
# Epoch [6/15], Iter [160,430] Loss:0.8651, average_loss: 0.9499
# Epoch [6/15], Iter [170,430] Loss:0.4781, average_loss: 0.9501
# Epoch [6/15], Iter [180,430] Loss:0.8155, average_loss: 0.9492
# Epoch [6/15], Iter [190,430] Loss:1.1769, average_loss: 0.9571
# Epoch [6/15], Iter [200,430] Loss:0.5144, average_loss: 0.9571
# Epoch [6/15], Iter [210,430] Loss:1.1347, average_loss: 0.9560
# Epoch [6/15], Iter [220,430] Loss:1.4337, average_loss: 0.9595
# Epoch [6/15], Iter [230,430] Loss:1.1739, average_loss: 0.9517
# Epoch [6/15], Iter [240,430] Loss:1.6100, average_loss: 0.9520
# Epoch [6/15], Iter [250,430] Loss:0.8797, average_loss: 0.9487
# Epoch [6/15], Iter [260,430] Loss:0.8061, average_loss: 0.9469
# Epoch [6/15], Iter [270,430] Loss:0.7979, average_loss: 0.9496
# Epoch [6/15], Iter [280,430] Loss:0.7636, average_loss: 0.9497
# Epoch [6/15], Iter [290,430] Loss:0.8480, average_loss: 0.9501
# Epoch [6/15], Iter [300,430] Loss:1.6112, average_loss: 0.9508
# Epoch [6/15], Iter [310,430] Loss:0.5955, average_loss: 0.9455
# Epoch [6/15], Iter [320,430] Loss:0.8816, average_loss: 0.9414
# Epoch [6/15], Iter [330,430] Loss:0.6950, average_loss: 0.9427
# Epoch [6/15], Iter [340,430] Loss:1.2457, average_loss: 0.9435
# Epoch [6/15], Iter [350,430] Loss:0.8660, average_loss: 0.9411
# Epoch [6/15], Iter [360,430] Loss:0.8206, average_loss: 0.9441
# Epoch [6/15], Iter [370,430] Loss:1.0142, average_loss: 0.9409
# Epoch [6/15], Iter [380,430] Loss:1.1997, average_loss: 0.9380
# Epoch [6/15], Iter [390,430] Loss:0.9245, average_loss: 0.9418
# Epoch [6/15], Iter [400,430] Loss:0.5060, average_loss: 0.9396
# Epoch [6/15], Iter [410,430] Loss:0.7335, average_loss: 0.9396
# Epoch [6/15], Iter [420,430] Loss:0.7589, average_loss: 0.9414
# Epoch [6/15], Iter [430,430] Loss:0.4985, average_loss: 0.9420
# Epoch [7/15], Iter [10,430] Loss:0.6439, average_loss: 0.9724
# Epoch [7/15], Iter [20,430] Loss:0.9646, average_loss: 0.9525
# Epoch [7/15], Iter [30,430] Loss:1.3768, average_loss: 0.9369
# Epoch [7/15], Iter [40,430] Loss:1.8533, average_loss: 0.9740
# Epoch [7/15], Iter [50,430] Loss:1.0991, average_loss: 0.9724
# Epoch [7/15], Iter [60,430] Loss:0.8423, average_loss: 0.9647
# Epoch [7/15], Iter [70,430] Loss:1.6154, average_loss: 0.9849
# Epoch [7/15], Iter [80,430] Loss:0.6447, average_loss: 0.9743
# Epoch [7/15], Iter [90,430] Loss:0.6577, average_loss: 0.9613
# Epoch [7/15], Iter [100,430] Loss:1.5051, average_loss: 0.9585
# Epoch [7/15], Iter [110,430] Loss:0.8387, average_loss: 0.9627
# Epoch [7/15], Iter [120,430] Loss:0.9834, average_loss: 0.9554
# Epoch [7/15], Iter [130,430] Loss:0.6630, average_loss: 0.9399
# Epoch [7/15], Iter [140,430] Loss:0.4716, average_loss: 0.9305
# Epoch [7/15], Iter [150,430] Loss:0.6334, average_loss: 0.9247
# Epoch [7/15], Iter [160,430] Loss:2.1684, average_loss: 0.9266
# Epoch [7/15], Iter [170,430] Loss:0.5101, average_loss: 0.9288
# Epoch [7/15], Iter [180,430] Loss:0.4477, average_loss: 0.9242
# Epoch [7/15], Iter [190,430] Loss:0.5651, average_loss: 0.9223
# Epoch [7/15], Iter [200,430] Loss:0.9648, average_loss: 0.9161
# Epoch [7/15], Iter [210,430] Loss:0.9769, average_loss: 0.9145
# Epoch [7/15], Iter [220,430] Loss:0.7739, average_loss: 0.9112
# Epoch [7/15], Iter [230,430] Loss:0.6614, average_loss: 0.9063
# Epoch [7/15], Iter [240,430] Loss:0.7882, average_loss: 0.9004
# Epoch [7/15], Iter [250,430] Loss:1.1185, average_loss: 0.8983
# Epoch [7/15], Iter [260,430] Loss:0.7811, average_loss: 0.9001
# Epoch [7/15], Iter [270,430] Loss:0.5583, average_loss: 0.8984
# Epoch [7/15], Iter [280,430] Loss:0.6706, average_loss: 0.9015
# Epoch [7/15], Iter [290,430] Loss:1.0259, average_loss: 0.8971
# Epoch [7/15], Iter [300,430] Loss:0.7026, average_loss: 0.8972
# Epoch [7/15], Iter [310,430] Loss:0.6930, average_loss: 0.8944
# Epoch [7/15], Iter [320,430] Loss:0.9842, average_loss: 0.8988
# Epoch [7/15], Iter [330,430] Loss:1.2480, average_loss: 0.8994
# Epoch [7/15], Iter [340,430] Loss:0.6706, average_loss: 0.8951
# Epoch [7/15], Iter [350,430] Loss:0.6588, average_loss: 0.8876
# Epoch [7/15], Iter [360,430] Loss:1.0581, average_loss: 0.8867
# Epoch [7/15], Iter [370,430] Loss:0.4259, average_loss: 0.8827
# Epoch [7/15], Iter [380,430] Loss:1.0470, average_loss: 0.8803
# Epoch [7/15], Iter [390,430] Loss:0.5350, average_loss: 0.8762
# Epoch [7/15], Iter [400,430] Loss:0.7891, average_loss: 0.8800
# Epoch [7/15], Iter [410,430] Loss:0.7054, average_loss: 0.8780
# Epoch [7/15], Iter [420,430] Loss:0.6740, average_loss: 0.8827
# Epoch [7/15], Iter [430,430] Loss:1.2861, average_loss: 0.8837
# Epoch [8/15], Iter [10,430] Loss:0.9644, average_loss: 0.9219
# Epoch [8/15], Iter [20,430] Loss:0.6904, average_loss: 0.8700
# Epoch [8/15], Iter [30,430] Loss:0.6525, average_loss: 0.8882
# Epoch [8/15], Iter [40,430] Loss:0.7713, average_loss: 0.8610
# Epoch [8/15], Iter [50,430] Loss:0.7943, average_loss: 0.8851
# Epoch [8/15], Iter [60,430] Loss:0.7778, average_loss: 0.8655
# Epoch [8/15], Iter [70,430] Loss:0.7099, average_loss: 0.8593
# Epoch [8/15], Iter [80,430] Loss:1.1361, average_loss: 0.8658
# Epoch [8/15], Iter [90,430] Loss:1.2209, average_loss: 0.8894
# Epoch [8/15], Iter [100,430] Loss:1.0483, average_loss: 0.8818
# Epoch [8/15], Iter [110,430] Loss:1.5513, average_loss: 0.8910
# Epoch [8/15], Iter [120,430] Loss:1.2783, average_loss: 0.8753
# Epoch [8/15], Iter [130,430] Loss:1.2404, average_loss: 0.8706
# Epoch [8/15], Iter [140,430] Loss:1.0224, average_loss: 0.8851
# Epoch [8/15], Iter [150,430] Loss:0.7324, average_loss: 0.8758
# Epoch [8/15], Iter [160,430] Loss:0.7116, average_loss: 0.8751
# Epoch [8/15], Iter [170,430] Loss:0.6572, average_loss: 0.8789
# Epoch [8/15], Iter [180,430] Loss:0.8768, average_loss: 0.8748
# Epoch [8/15], Iter [190,430] Loss:0.5740, average_loss: 0.8852
# Epoch [8/15], Iter [200,430] Loss:0.8338, average_loss: 0.8792
# Epoch [8/15], Iter [210,430] Loss:0.3566, average_loss: 0.8788
# Epoch [8/15], Iter [220,430] Loss:1.2630, average_loss: 0.8812
# Epoch [8/15], Iter [230,430] Loss:0.8381, average_loss: 0.8774
# Epoch [8/15], Iter [240,430] Loss:0.7424, average_loss: 0.8763
# Epoch [8/15], Iter [250,430] Loss:1.0876, average_loss: 0.8799
# Epoch [8/15], Iter [260,430] Loss:0.8259, average_loss: 0.8741
# Epoch [8/15], Iter [270,430] Loss:0.6748, average_loss: 0.8721
# Epoch [8/15], Iter [280,430] Loss:0.7160, average_loss: 0.8731
# Epoch [8/15], Iter [290,430] Loss:0.9809, average_loss: 0.8749
# Epoch [8/15], Iter [300,430] Loss:1.7881, average_loss: 0.8669
# Epoch [8/15], Iter [310,430] Loss:0.6457, average_loss: 0.8692
# Epoch [8/15], Iter [320,430] Loss:0.4878, average_loss: 0.8665
# Epoch [8/15], Iter [330,430] Loss:1.1405, average_loss: 0.8661
# Epoch [8/15], Iter [340,430] Loss:0.8820, average_loss: 0.8661
# Epoch [8/15], Iter [350,430] Loss:0.9766, average_loss: 0.8721
# Epoch [8/15], Iter [360,430] Loss:1.5590, average_loss: 0.8722
# Epoch [8/15], Iter [370,430] Loss:0.8137, average_loss: 0.8733
# Epoch [8/15], Iter [380,430] Loss:0.7522, average_loss: 0.8706
# Epoch [8/15], Iter [390,430] Loss:0.8630, average_loss: 0.8731
# Epoch [8/15], Iter [400,430] Loss:0.9304, average_loss: 0.8690
# Epoch [8/15], Iter [410,430] Loss:0.4966, average_loss: 0.8667
# Epoch [8/15], Iter [420,430] Loss:0.5520, average_loss: 0.8620
# Epoch [8/15], Iter [430,430] Loss:0.6222, average_loss: 0.8595
# Epoch [9/15], Iter [10,430] Loss:0.6144, average_loss: 0.8412
# Epoch [9/15], Iter [20,430] Loss:0.7276, average_loss: 0.8093
# Epoch [9/15], Iter [30,430] Loss:0.8670, average_loss: 0.7852
# Epoch [9/15], Iter [40,430] Loss:0.3738, average_loss: 0.8028
# Epoch [9/15], Iter [50,430] Loss:1.1313, average_loss: 0.8027
# Epoch [9/15], Iter [60,430] Loss:0.8915, average_loss: 0.7992
# Epoch [9/15], Iter [70,430] Loss:0.9200, average_loss: 0.8065
# Epoch [9/15], Iter [80,430] Loss:0.7687, average_loss: 0.7997
# Epoch [9/15], Iter [90,430] Loss:0.4882, average_loss: 0.7918
# Epoch [9/15], Iter [100,430] Loss:0.5506, average_loss: 0.7871
# Epoch [9/15], Iter [110,430] Loss:0.7859, average_loss: 0.7900
# Epoch [9/15], Iter [120,430] Loss:0.9570, average_loss: 0.7971
# Epoch [9/15], Iter [130,430] Loss:0.7653, average_loss: 0.7916
# Epoch [9/15], Iter [140,430] Loss:1.1763, average_loss: 0.7965
# Epoch [9/15], Iter [150,430] Loss:0.9884, average_loss: 0.7999
# Epoch [9/15], Iter [160,430] Loss:1.1114, average_loss: 0.7998
# Epoch [9/15], Iter [170,430] Loss:0.7100, average_loss: 0.8034
# Epoch [9/15], Iter [180,430] Loss:0.5525, average_loss: 0.8058
# Epoch [9/15], Iter [190,430] Loss:0.3516, average_loss: 0.8001
# Epoch [9/15], Iter [200,430] Loss:1.1181, average_loss: 0.8011
# Epoch [9/15], Iter [210,430] Loss:0.6743, average_loss: 0.7960
# Epoch [9/15], Iter [220,430] Loss:0.6354, average_loss: 0.8076
# Epoch [9/15], Iter [230,430] Loss:0.7577, average_loss: 0.8087
# Epoch [9/15], Iter [240,430] Loss:0.5826, average_loss: 0.8108
# Epoch [9/15], Iter [250,430] Loss:0.6477, average_loss: 0.8072
# Epoch [9/15], Iter [260,430] Loss:1.0375, average_loss: 0.8074
# Epoch [9/15], Iter [270,430] Loss:0.6238, average_loss: 0.8030
# Epoch [9/15], Iter [280,430] Loss:0.5374, average_loss: 0.8127
# Epoch [9/15], Iter [290,430] Loss:0.5187, average_loss: 0.8085
# Epoch [9/15], Iter [300,430] Loss:0.4209, average_loss: 0.8056
# Epoch [9/15], Iter [310,430] Loss:0.6222, average_loss: 0.8008
# Epoch [9/15], Iter [320,430] Loss:0.4178, average_loss: 0.7987
# Epoch [9/15], Iter [330,430] Loss:0.7188, average_loss: 0.7993
# Epoch [9/15], Iter [340,430] Loss:0.9600, average_loss: 0.8056
# Epoch [9/15], Iter [350,430] Loss:0.9120, average_loss: 0.8024
# Epoch [9/15], Iter [360,430] Loss:0.9150, average_loss: 0.8045
# Epoch [9/15], Iter [370,430] Loss:1.0002, average_loss: 0.8075
# Epoch [9/15], Iter [380,430] Loss:0.7110, average_loss: 0.8092
# Epoch [9/15], Iter [390,430] Loss:0.7433, average_loss: 0.8173
# Epoch [9/15], Iter [400,430] Loss:0.5525, average_loss: 0.8183
# Epoch [9/15], Iter [410,430] Loss:1.1372, average_loss: 0.8197
# Epoch [9/15], Iter [420,430] Loss:0.7245, average_loss: 0.8204
# Epoch [9/15], Iter [430,430] Loss:0.7487, average_loss: 0.8215
# Epoch [10/15], Iter [10,430] Loss:0.6288, average_loss: 0.7847
# Epoch [10/15], Iter [20,430] Loss:0.9191, average_loss: 0.8330
# Epoch [10/15], Iter [30,430] Loss:0.4870, average_loss: 0.8104
# Epoch [10/15], Iter [40,430] Loss:0.6777, average_loss: 0.7852
# Epoch [10/15], Iter [50,430] Loss:0.7297, average_loss: 0.7732
# Epoch [10/15], Iter [60,430] Loss:0.7250, average_loss: 0.7653
# Epoch [10/15], Iter [70,430] Loss:0.3412, average_loss: 0.7493
# Epoch [10/15], Iter [80,430] Loss:1.2468, average_loss: 0.7703
# Epoch [10/15], Iter [90,430] Loss:0.6677, average_loss: 0.7723
# Epoch [10/15], Iter [100,430] Loss:0.5639, average_loss: 0.7813
# Epoch [10/15], Iter [110,430] Loss:0.8094, average_loss: 0.7816
# Epoch [10/15], Iter [120,430] Loss:0.4772, average_loss: 0.7863
# Epoch [10/15], Iter [130,430] Loss:0.7402, average_loss: 0.7882
# Epoch [10/15], Iter [140,430] Loss:0.7830, average_loss: 0.7891
# Epoch [10/15], Iter [150,430] Loss:0.4792, average_loss: 0.7910
# Epoch [10/15], Iter [160,430] Loss:0.6254, average_loss: 0.7950
# Epoch [10/15], Iter [170,430] Loss:0.5442, average_loss: 0.7943
# Epoch [10/15], Iter [180,430] Loss:1.1732, average_loss: 0.8020
# Epoch [10/15], Iter [190,430] Loss:0.6711, average_loss: 0.8076
# Epoch [10/15], Iter [200,430] Loss:0.5832, average_loss: 0.8144
# Epoch [10/15], Iter [210,430] Loss:0.5502, average_loss: 0.8108
# Epoch [10/15], Iter [220,430] Loss:0.7837, average_loss: 0.8055
# Epoch [10/15], Iter [230,430] Loss:0.8210, average_loss: 0.8051
# Epoch [10/15], Iter [240,430] Loss:0.5114, average_loss: 0.7973
# Epoch [10/15], Iter [250,430] Loss:0.5405, average_loss: 0.7957
# Epoch [10/15], Iter [260,430] Loss:0.5104, average_loss: 0.8005
# Epoch [10/15], Iter [270,430] Loss:1.0016, average_loss: 0.8018
# Epoch [10/15], Iter [280,430] Loss:0.6265, average_loss: 0.8010
# Epoch [10/15], Iter [290,430] Loss:0.3556, average_loss: 0.7932
# Epoch [10/15], Iter [300,430] Loss:0.8771, average_loss: 0.7937
# Epoch [10/15], Iter [310,430] Loss:0.5303, average_loss: 0.7936
# Epoch [10/15], Iter [320,430] Loss:0.6232, average_loss: 0.7898
# Epoch [10/15], Iter [330,430] Loss:0.9461, average_loss: 0.7899
# Epoch [10/15], Iter [340,430] Loss:0.9567, average_loss: 0.7892
# Epoch [10/15], Iter [350,430] Loss:0.5831, average_loss: 0.7927
# Epoch [10/15], Iter [360,430] Loss:0.6768, average_loss: 0.7884
# Epoch [10/15], Iter [370,430] Loss:0.6244, average_loss: 0.7847
# Epoch [10/15], Iter [380,430] Loss:0.4864, average_loss: 0.7804
# Epoch [10/15], Iter [390,430] Loss:0.5204, average_loss: 0.7791
# Epoch [10/15], Iter [400,430] Loss:0.5357, average_loss: 0.7787
# Epoch [10/15], Iter [410,430] Loss:1.9661, average_loss: 0.7809
# Epoch [10/15], Iter [420,430] Loss:1.1195, average_loss: 0.7817
# Epoch [10/15], Iter [430,430] Loss:0.5938, average_loss: 0.7818
# Epoch [11/15], Iter [10,430] Loss:0.4918, average_loss: 0.7227
# Epoch [11/15], Iter [20,430] Loss:0.9146, average_loss: 0.7775
# Epoch [11/15], Iter [30,430] Loss:0.5339, average_loss: 0.7508
# Epoch [11/15], Iter [40,430] Loss:0.5815, average_loss: 0.7429
# Epoch [11/15], Iter [50,430] Loss:0.4945, average_loss: 0.7541
# Epoch [11/15], Iter [60,430] Loss:0.9425, average_loss: 0.7642
# Epoch [11/15], Iter [70,430] Loss:0.8955, average_loss: 0.7599
# Epoch [11/15], Iter [80,430] Loss:0.8106, average_loss: 0.7552
# Epoch [11/15], Iter [90,430] Loss:0.9159, average_loss: 0.7541
# Epoch [11/15], Iter [100,430] Loss:0.5834, average_loss: 0.7540
# Epoch [11/15], Iter [110,430] Loss:0.7950, average_loss: 0.7408
# Epoch [11/15], Iter [120,430] Loss:0.8497, average_loss: 0.7393
# Epoch [11/15], Iter [130,430] Loss:0.9577, average_loss: 0.7376
# Epoch [11/15], Iter [140,430] Loss:1.2825, average_loss: 0.7437
# Epoch [11/15], Iter [150,430] Loss:0.3657, average_loss: 0.7481
# Epoch [11/15], Iter [160,430] Loss:0.7916, average_loss: 0.7585
# Epoch [11/15], Iter [170,430] Loss:0.9072, average_loss: 0.7687
# Epoch [11/15], Iter [180,430] Loss:1.0354, average_loss: 0.7730
# Epoch [11/15], Iter [190,430] Loss:0.6924, average_loss: 0.7746
# Epoch [11/15], Iter [200,430] Loss:0.5118, average_loss: 0.7722
# Epoch [11/15], Iter [210,430] Loss:0.9776, average_loss: 0.7705
# Epoch [11/15], Iter [220,430] Loss:0.6952, average_loss: 0.7660
# Epoch [11/15], Iter [230,430] Loss:1.4875, average_loss: 0.7682
# Epoch [11/15], Iter [240,430] Loss:0.6658, average_loss: 0.7633
# Epoch [11/15], Iter [250,430] Loss:0.8015, average_loss: 0.7642
# Epoch [11/15], Iter [260,430] Loss:0.7435, average_loss: 0.7662
# Epoch [11/15], Iter [270,430] Loss:0.7823, average_loss: 0.7682
# Epoch [11/15], Iter [280,430] Loss:0.5143, average_loss: 0.7671
# Epoch [11/15], Iter [290,430] Loss:0.8819, average_loss: 0.7651
# Epoch [11/15], Iter [300,430] Loss:0.4579, average_loss: 0.7647
# Epoch [11/15], Iter [310,430] Loss:1.1209, average_loss: 0.7617
# Epoch [11/15], Iter [320,430] Loss:0.5979, average_loss: 0.7611
# Epoch [11/15], Iter [330,430] Loss:0.4764, average_loss: 0.7589
# Epoch [11/15], Iter [340,430] Loss:0.8115, average_loss: 0.7557
# Epoch [11/15], Iter [350,430] Loss:0.6277, average_loss: 0.7559
# Epoch [11/15], Iter [360,430] Loss:0.6021, average_loss: 0.7547
# Epoch [11/15], Iter [370,430] Loss:0.6624, average_loss: 0.7546
# Epoch [11/15], Iter [380,430] Loss:0.7132, average_loss: 0.7566
# Epoch [11/15], Iter [390,430] Loss:0.3871, average_loss: 0.7555
# Epoch [11/15], Iter [400,430] Loss:0.6800, average_loss: 0.7539
# Epoch [11/15], Iter [410,430] Loss:0.5207, average_loss: 0.7525
# Epoch [11/15], Iter [420,430] Loss:0.4763, average_loss: 0.7521
# Epoch [11/15], Iter [430,430] Loss:0.4643, average_loss: 0.7524
# Epoch [12/15], Iter [10,430] Loss:0.6408, average_loss: 0.7392
# Epoch [12/15], Iter [20,430] Loss:1.0578, average_loss: 0.7160
# Epoch [12/15], Iter [30,430] Loss:0.4610, average_loss: 0.7299
# Epoch [12/15], Iter [40,430] Loss:0.9153, average_loss: 0.7239
# Epoch [12/15], Iter [50,430] Loss:0.3719, average_loss: 0.7411
# Epoch [12/15], Iter [60,430] Loss:1.0007, average_loss: 0.7355
# Epoch [12/15], Iter [70,430] Loss:0.5497, average_loss: 0.7305
# Epoch [12/15], Iter [80,430] Loss:0.5708, average_loss: 0.7341
# Epoch [12/15], Iter [90,430] Loss:0.7835, average_loss: 0.7261
# Epoch [12/15], Iter [100,430] Loss:1.0826, average_loss: 0.7481
# Epoch [12/15], Iter [110,430] Loss:0.5237, average_loss: 0.7406
# Epoch [12/15], Iter [120,430] Loss:0.4047, average_loss: 0.7421
# Epoch [12/15], Iter [130,430] Loss:0.7438, average_loss: 0.7474
# Epoch [12/15], Iter [140,430] Loss:0.7436, average_loss: 0.7414
# Epoch [12/15], Iter [150,430] Loss:0.6569, average_loss: 0.7366
# Epoch [12/15], Iter [160,430] Loss:1.5015, average_loss: 0.7392
# Epoch [12/15], Iter [170,430] Loss:2.0488, average_loss: 0.7446
# Epoch [12/15], Iter [180,430] Loss:0.7907, average_loss: 0.7415
# Epoch [12/15], Iter [190,430] Loss:1.0214, average_loss: 0.7483
# Epoch [12/15], Iter [200,430] Loss:0.7515, average_loss: 0.7562
# Epoch [12/15], Iter [210,430] Loss:0.5799, average_loss: 0.7535
# Epoch [12/15], Iter [220,430] Loss:1.0069, average_loss: 0.7525
# Epoch [12/15], Iter [230,430] Loss:0.6156, average_loss: 0.7465
# Epoch [12/15], Iter [240,430] Loss:0.8316, average_loss: 0.7440
# Epoch [12/15], Iter [250,430] Loss:0.8739, average_loss: 0.7443
# Epoch [12/15], Iter [260,430] Loss:0.6549, average_loss: 0.7454
# Epoch [12/15], Iter [270,430] Loss:0.7995, average_loss: 0.7472
# Epoch [12/15], Iter [280,430] Loss:0.6734, average_loss: 0.7456
# Epoch [12/15], Iter [290,430] Loss:1.1813, average_loss: 0.7504
# Epoch [12/15], Iter [300,430] Loss:0.3040, average_loss: 0.7483
# Epoch [12/15], Iter [310,430] Loss:0.5635, average_loss: 0.7507
# Epoch [12/15], Iter [320,430] Loss:1.1147, average_loss: 0.7532
# Epoch [12/15], Iter [330,430] Loss:1.1523, average_loss: 0.7517
# Epoch [12/15], Iter [340,430] Loss:0.8135, average_loss: 0.7494
# Epoch [12/15], Iter [350,430] Loss:0.4691, average_loss: 0.7489
# Epoch [12/15], Iter [360,430] Loss:0.5857, average_loss: 0.7470
# Epoch [12/15], Iter [370,430] Loss:1.0989, average_loss: 0.7439
# Epoch [12/15], Iter [380,430] Loss:0.6116, average_loss: 0.7416
# Epoch [12/15], Iter [390,430] Loss:0.6158, average_loss: 0.7398
# Epoch [12/15], Iter [400,430] Loss:0.5720, average_loss: 0.7385
# Epoch [12/15], Iter [410,430] Loss:1.2962, average_loss: 0.7397
# Epoch [12/15], Iter [420,430] Loss:1.3873, average_loss: 0.7422
# Epoch [12/15], Iter [430,430] Loss:0.8736, average_loss: 0.7446
# Epoch [13/15], Iter [10,430] Loss:0.6202, average_loss: 0.6798
# Epoch [13/15], Iter [20,430] Loss:0.6856, average_loss: 0.6675
# Epoch [13/15], Iter [30,430] Loss:0.5465, average_loss: 0.6650
# Epoch [13/15], Iter [40,430] Loss:0.4734, average_loss: 0.6733
# Epoch [13/15], Iter [50,430] Loss:0.4131, average_loss: 0.6905
# Epoch [13/15], Iter [60,430] Loss:0.6934, average_loss: 0.7111
# Epoch [13/15], Iter [70,430] Loss:0.3476, average_loss: 0.7158
# Epoch [13/15], Iter [80,430] Loss:0.8187, average_loss: 0.7019
# Epoch [13/15], Iter [90,430] Loss:0.6614, average_loss: 0.7031
# Epoch [13/15], Iter [100,430] Loss:0.8732, average_loss: 0.7140
# Epoch [13/15], Iter [110,430] Loss:1.0724, average_loss: 0.7302
# Epoch [13/15], Iter [120,430] Loss:1.1247, average_loss: 0.7296
# Epoch [13/15], Iter [130,430] Loss:0.8584, average_loss: 0.7337
# Epoch [13/15], Iter [140,430] Loss:1.0635, average_loss: 0.7417
# Epoch [13/15], Iter [150,430] Loss:0.7101, average_loss: 0.7385
# Epoch [13/15], Iter [160,430] Loss:0.7827, average_loss: 0.7422
# Epoch [13/15], Iter [170,430] Loss:1.0217, average_loss: 0.7468
# Epoch [13/15], Iter [180,430] Loss:0.9514, average_loss: 0.7459
# Epoch [13/15], Iter [190,430] Loss:0.9052, average_loss: 0.7446
# Epoch [13/15], Iter [200,430] Loss:1.0700, average_loss: 0.7462
# Epoch [13/15], Iter [210,430] Loss:1.0189, average_loss: 0.7463
# Epoch [13/15], Iter [220,430] Loss:0.6305, average_loss: 0.7476
# Epoch [13/15], Iter [230,430] Loss:0.7952, average_loss: 0.7538
# Epoch [13/15], Iter [240,430] Loss:0.7436, average_loss: 0.7524
# Epoch [13/15], Iter [250,430] Loss:0.6523, average_loss: 0.7519
# Epoch [13/15], Iter [260,430] Loss:0.5536, average_loss: 0.7524
# Epoch [13/15], Iter [270,430] Loss:1.1110, average_loss: 0.7494
# Epoch [13/15], Iter [280,430] Loss:0.9439, average_loss: 0.7494
# Epoch [13/15], Iter [290,430] Loss:0.7096, average_loss: 0.7546
# Epoch [13/15], Iter [300,430] Loss:0.7727, average_loss: 0.7537
# Epoch [13/15], Iter [310,430] Loss:0.6100, average_loss: 0.7493
# Epoch [13/15], Iter [320,430] Loss:1.2429, average_loss: 0.7511
# Epoch [13/15], Iter [330,430] Loss:0.6424, average_loss: 0.7503
# Epoch [13/15], Iter [340,430] Loss:0.8234, average_loss: 0.7500
# Epoch [13/15], Iter [350,430] Loss:0.5165, average_loss: 0.7476
# Epoch [13/15], Iter [360,430] Loss:1.1145, average_loss: 0.7454
# Epoch [13/15], Iter [370,430] Loss:0.7376, average_loss: 0.7457
# Epoch [13/15], Iter [380,430] Loss:0.4698, average_loss: 0.7440
# Epoch [13/15], Iter [390,430] Loss:0.6683, average_loss: 0.7397
# Epoch [13/15], Iter [400,430] Loss:1.0367, average_loss: 0.7416
# Epoch [13/15], Iter [410,430] Loss:0.8835, average_loss: 0.7418
# Epoch [13/15], Iter [420,430] Loss:0.6560, average_loss: 0.7419
# Epoch [13/15], Iter [430,430] Loss:1.4689, average_loss: 0.7425
# Epoch [14/15], Iter [10,430] Loss:1.1164, average_loss: 0.8574
# Epoch [14/15], Iter [20,430] Loss:0.6565, average_loss: 0.8400
# Epoch [14/15], Iter [30,430] Loss:0.4839, average_loss: 0.8166
# Epoch [14/15], Iter [40,430] Loss:0.7636, average_loss: 0.8143
# Epoch [14/15], Iter [50,430] Loss:0.6990, average_loss: 0.7779
# Epoch [14/15], Iter [60,430] Loss:0.4680, average_loss: 0.7554
# Epoch [14/15], Iter [70,430] Loss:0.5156, average_loss: 0.7370
# Epoch [14/15], Iter [80,430] Loss:0.9850, average_loss: 0.7335
# Epoch [14/15], Iter [90,430] Loss:0.4529, average_loss: 0.7368
# Epoch [14/15], Iter [100,430] Loss:0.8575, average_loss: 0.7354
# Epoch [14/15], Iter [110,430] Loss:0.6882, average_loss: 0.7342
# Epoch [14/15], Iter [120,430] Loss:0.5060, average_loss: 0.7256
# Epoch [14/15], Iter [130,430] Loss:0.9027, average_loss: 0.7292
# Epoch [14/15], Iter [140,430] Loss:0.4088, average_loss: 0.7238
# Epoch [14/15], Iter [150,430] Loss:0.6522, average_loss: 0.7264
# Epoch [14/15], Iter [160,430] Loss:0.6348, average_loss: 0.7253
# Epoch [14/15], Iter [170,430] Loss:0.4109, average_loss: 0.7234
# Epoch [14/15], Iter [180,430] Loss:0.4435, average_loss: 0.7229
# Epoch [14/15], Iter [190,430] Loss:0.6403, average_loss: 0.7175
# Epoch [14/15], Iter [200,430] Loss:0.4585, average_loss: 0.7148
# Epoch [14/15], Iter [210,430] Loss:0.4568, average_loss: 0.7076
# Epoch [14/15], Iter [220,430] Loss:0.7442, average_loss: 0.7059
# Epoch [14/15], Iter [230,430] Loss:0.5598, average_loss: 0.7035
# Epoch [14/15], Iter [240,430] Loss:1.0904, average_loss: 0.7039
# Epoch [14/15], Iter [250,430] Loss:0.4544, average_loss: 0.6999
# Epoch [14/15], Iter [260,430] Loss:0.7054, average_loss: 0.7011
# Epoch [14/15], Iter [270,430] Loss:0.3853, average_loss: 0.6998
# Epoch [14/15], Iter [280,430] Loss:0.6461, average_loss: 0.7007
# Epoch [14/15], Iter [290,430] Loss:0.6742, average_loss: 0.6952
# Epoch [14/15], Iter [300,430] Loss:0.6928, average_loss: 0.6942
# Epoch [14/15], Iter [310,430] Loss:0.5810, average_loss: 0.6905
# Epoch [14/15], Iter [320,430] Loss:0.8493, average_loss: 0.6933
# Epoch [14/15], Iter [330,430] Loss:0.7250, average_loss: 0.6951
# Epoch [14/15], Iter [340,430] Loss:0.8422, average_loss: 0.6942
# Epoch [14/15], Iter [350,430] Loss:0.8358, average_loss: 0.6983
# Epoch [14/15], Iter [360,430] Loss:0.7198, average_loss: 0.6982
# Epoch [14/15], Iter [370,430] Loss:0.7769, average_loss: 0.7021
# Epoch [14/15], Iter [380,430] Loss:0.5269, average_loss: 0.7015
# Epoch [14/15], Iter [390,430] Loss:0.7706, average_loss: 0.6992
# Epoch [14/15], Iter [400,430] Loss:1.1291, average_loss: 0.7010
# Epoch [14/15], Iter [410,430] Loss:0.5833, average_loss: 0.7034
# Epoch [14/15], Iter [420,430] Loss:0.6892, average_loss: 0.7018
# Epoch [14/15], Iter [430,430] Loss:0.5845, average_loss: 0.7012
# Epoch [15/15], Iter [10,430] Loss:0.4494, average_loss: 0.6971
# Epoch [15/15], Iter [20,430] Loss:0.4793, average_loss: 0.6260
# Epoch [15/15], Iter [30,430] Loss:0.6211, average_loss: 0.6577
# Epoch [15/15], Iter [40,430] Loss:0.6913, average_loss: 0.6476
# Epoch [15/15], Iter [50,430] Loss:0.6226, average_loss: 0.6650
# Epoch [15/15], Iter [60,430] Loss:1.1601, average_loss: 0.6546
# Epoch [15/15], Iter [70,430] Loss:0.6060, average_loss: 0.6561
# Epoch [15/15], Iter [80,430] Loss:0.6537, average_loss: 0.6741
# Epoch [15/15], Iter [90,430] Loss:0.6177, average_loss: 0.6812
# Epoch [15/15], Iter [100,430] Loss:0.2670, average_loss: 0.6826
# Epoch [15/15], Iter [110,430] Loss:0.4508, average_loss: 0.6758
# Epoch [15/15], Iter [120,430] Loss:0.4103, average_loss: 0.6716
# Epoch [15/15], Iter [130,430] Loss:0.6458, average_loss: 0.6831
# Epoch [15/15], Iter [140,430] Loss:0.8924, average_loss: 0.6799
# Epoch [15/15], Iter [150,430] Loss:0.5921, average_loss: 0.6797
# Epoch [15/15], Iter [160,430] Loss:0.8839, average_loss: 0.6771
# Epoch [15/15], Iter [170,430] Loss:0.6454, average_loss: 0.6761
# Epoch [15/15], Iter [180,430] Loss:0.7743, average_loss: 0.6781
# Epoch [15/15], Iter [190,430] Loss:0.8462, average_loss: 0.6743
# Epoch [15/15], Iter [200,430] Loss:0.6854, average_loss: 0.6736
# Epoch [15/15], Iter [210,430] Loss:0.6470, average_loss: 0.6692
# Epoch [15/15], Iter [220,430] Loss:0.6499, average_loss: 0.6701
# Epoch [15/15], Iter [230,430] Loss:0.5347, average_loss: 0.6735
# Epoch [15/15], Iter [240,430] Loss:0.5928, average_loss: 0.6731
# Epoch [15/15], Iter [250,430] Loss:0.4457, average_loss: 0.6736
# Epoch [15/15], Iter [260,430] Loss:0.4180, average_loss: 0.6755
# Epoch [15/15], Iter [270,430] Loss:0.9443, average_loss: 0.6739
# Epoch [15/15], Iter [280,430] Loss:0.5954, average_loss: 0.6757
# Epoch [15/15], Iter [290,430] Loss:0.8372, average_loss: 0.6777
# Epoch [15/15], Iter [300,430] Loss:0.3897, average_loss: 0.6767
# Epoch [15/15], Iter [310,430] Loss:0.9250, average_loss: 0.6750
# Epoch [15/15], Iter [320,430] Loss:0.8133, average_loss: 0.6751
# Epoch [15/15], Iter [330,430] Loss:0.4199, average_loss: 0.6793
# Epoch [15/15], Iter [340,430] Loss:0.4952, average_loss: 0.6777
# Epoch [15/15], Iter [350,430] Loss:0.6300, average_loss: 0.6793
# Epoch [15/15], Iter [360,430] Loss:0.9356, average_loss: 0.6774
# Epoch [15/15], Iter [370,430] Loss:0.5735, average_loss: 0.6808
# Epoch [15/15], Iter [380,430] Loss:0.7204, average_loss: 0.6836
# Epoch [15/15], Iter [390,430] Loss:0.7028, average_loss: 0.6844
# Epoch [15/15], Iter [400,430] Loss:0.5275, average_loss: 0.6836
# Epoch [15/15], Iter [410,430] Loss:0.7305, average_loss: 0.6828
# Epoch [15/15], Iter [420,430] Loss:0.9444, average_loss: 0.6869
# Epoch [15/15], Iter [430,430] Loss:0.5974, average_loss: 0.6870

# %% [markdown]
# ### Step 5. Inference

# %% [markdown]
# ### Step 5-1. Inference (Visualizing)
# - The below code is for visualizing your results.
# - Check out!

# %%
## Visualizing the bouding box image
from lab2.utils.util import *

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

Color = [[0, 0, 0],
                    [128, 0, 0],
                    [0, 128, 0],
                    [128, 128, 0],
                    [0, 0, 128],
                    [128, 0, 128]]

def visualize(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()

    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0.1)

    for i, box in enumerate(boxes):

        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        result.append([(x1, y1), (x2, y2), SMALL_VOC_CLASSES[cls_index], prob])

    img = np.zeros((h, w, 3), np.uint8)
    img = img + image[:,:,::-1]

    for left_up,right_bottom,class_name,prob in result:
        color = Color[SMALL_VOC_CLASSES.index(class_name)]
        cv2.rectangle(img, left_up, right_bottom, color, 2)
        label = class_name+str(round(prob,2))
        text_size, baseline = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.4, 1)
        p1 = (left_up[0], left_up[1]- text_size[1])
        cv2.rectangle(img, (p1[0] - 2//2, p1[1] - 2 - baseline), (p1[0] + text_size[0], p1[1] + text_size[1]), color, -1)
        cv2.putText(img, label, (p1[0], p1[1] + baseline), cv2.FONT_HERSHEY_SIMPLEX, 0.4, (255,255,255), 1, 8)

    plt.imshow(img)

model.eval()
visualize(model, './lab2/utils/Generate_dataset/images/003033.jpg')
# Out:
# /tmp/ipykernel_2525680/3972083125.py:23: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img = Variable(img[None,:,:,:],volatile=True)

# %% [markdown]
# ### Step 6-2. Inference (mAP)
# - The below code is for checkout your network performance,
# - By using this code, your network prediction is saved in Generate_dataset directory
# - Then, %run ./lab2/utils/Generate_dataset/main.py
# - After a few seconds, the mAP is printed.
# - **Note that if your code is correct, the mAP will be over 70.**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

SMALL_VOC_CLASSES = ('aeroplane', 'bicycle', 'bus', 'car', 'cat', 'dog')

def write(model, path):
    result = []
    image = cv2.imread(path)
    h, w, _ = image.shape
    img = cv2.resize(image, (448, 448))
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    transform = transforms.Compose([transforms.ToTensor(),])
    img = 2 * transform(img) - 1
    img = Variable(img[None,:,:,:],volatile=True)
    img = img.cuda()

    pred = model(img) #1x7x7x30
    pred = pred.cpu()
    boxes,cls_indexs,probs =  interpret_target(pred, 0)

    txt_file = open('./lab2/utils/Generate_dataset/predicted/'+os.path.basename(path)[:-4]+'.txt', 'w')

    for i, box in enumerate(boxes):

        x1 = max(int(box[0] * w), 0)
        x2 = min(int(box[2] * w), w)
        y1 = max(int(box[1] * h), 0)
        y2 = min(int(box[3] * h), h)
        cls_index = cls_indexs[i]
        cls_index = int(cls_index)
        prob = probs[i]
        prob = float(prob)
        txt_file.write(str(SMALL_VOC_CLASSES[cls_index])+' '+'%.6f'%(prob)+' '+str(x1)+' '+str(y1)+' '+str(x2)+' '+str(y2))
        txt_file.write('\n')
    txt_file.close()

import glob

model.eval()
img_names = glob.glob('./lab2/utils/Generate_dataset/images/*')

for i, file_name in enumerate(img_names):
    write(model, file_name)
    if i % 500 == 0:
        print(i)
# Out:
# /tmp/ipykernel_2525680/3101837357.py:15: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   img = Variable(img[None,:,:,:],volatile=True)
# 0
# 500

# %%
# %run ./lab2/utils/Generate_dataset/main.py
# Out:
# 59.12% = aeroplane AP
# 62.18% = bicycle AP
# 59.88% = bus AP
# 63.48% = car AP
# 73.23% = cat AP
# 74.62% = dog AP
# mAP = 65.42%

# %% [markdown]
# ### *References*
# [1] https://www.pyimagesearch.com/2018/05/14/a-gentle-guide-to-deep-learning-object-detection/
#
# [2] https://github.com/Cartucho/mAP
